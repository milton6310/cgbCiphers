# %%
from pathlib import Path
from itertools import permutations
from nltk.corpus import words
from os.path import exists
import os
import pandas as pd
import re
import csv
import numpy as np
import matplotlib.pyplot as plt
import math
import itertools
import time
import random
import PySimpleGUI as sg
import wordninja

def saveFoundKeywordsAsFile(w_list, keyword, tag):
    fname_base = keyword + '-' + tag
    fpath = Path.cwd() / 'decoded' / fname_base
    np.save(fpath, np.array(w_list))
    print('Found Keywords saved: ', fpath, sep = '')
    return

def saveFoundKeywordsAsTextFile(w_list, keyword, tag):
    fname_base = keyword + '-' + tag + '.txt'
    fpath = Path.cwd() / 'decoded' / fname_base
    with open(fpath, 'w+', newline ='') as text_file:
        csv_writer = csv.writer(text_file)
        csv_writer.writerows(w_list)
        text_file.close();
    return

def rotateRotor(wiring, steps=1, forward=True):
    #print(wiring)
    A2Z = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    alen = len(A2Z)
    rotated = ""
    for i in range(len(A2Z)):
        if forward:
            j = (i + steps) % alen
            index = ((ord(wiring[j]) - ord('A') - steps) + alen) % alen
        else:
            j = ((i - steps) + alen) % alen
            index = ((ord(wiring[j]) - ord('A') + steps) + alen) % alen
        rotated = rotated + A2Z[index]
    #print(rotated)
    return rotated

def rotatedRotorList(wiring, steps=1, forward=True):
    w_array = []
    for i in range(len(wiring)):
        rr = rotateRotor(wiring, i)
        w_array.append(rr)
    return w_array

def saveRotatedRotorList(r_list, keyword):
    fname_base = 'rotated_' + keyword + '.txt'
    fpath = Path.cwd() / fname_base
    with open(fpath, 'w+', newline ='') as text_file:
        csv_writer = csv.writer(text_file)
        csv_writer.writerows(r_list)
        text_file.close();
    return

def reversedRotorWiring(wiring):
    revs_list = [" " for i in range(len(wiring))]
    for i in range(len(wiring)):
        c = wiring[i]
        index = ord(c) - ord('A')
        revs_list[index] = chr(ord('A') + i)
    revs = "".join(revs_list)
    return revs

def rotateReversedRotor(wiring, steps=1, forward=True):
    wiring = reversedRotorWiring(wiring)
    A2Z = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    alen = len(A2Z)
    rotated = ""
    for i in range(len(A2Z)):
        if forward:
            j = (i + steps) % alen
            index = ((ord(wiring[j]) - ord('A') - steps) + alen) % alen
        else:
            j = ((i - steps) + alen) % alen
            index = ((ord(wiring[j]) - ord('A') + steps) + alen) % alen
        rotated = rotated + A2Z[index]
    #print(rotated)
    return rotated

def rotatedReversedRotorList(wiring, steps=1, forward=True):
    w_array = []
    for i in range(len(wiring)):
        rr = rotateReversedRotor(wiring, i)
        w_array.append(rr)
    return w_array

def saveReversedRotatedRotorList(r_list, keyword):
    fname_base = 'reversed_rotated_' + keyword + '.txt'
    fpath = Path.cwd() / fname_base
    with open(fpath, 'w+', newline ='') as text_file:
        csv_writer = csv.writer(text_file)
        csv_writer.writerows(r_list)
        text_file.close();
    return

def isFreeConsonantMoreThan(word, minlen=0):
    if minlen <= 0:
        return False
    consonants = set("BCDFGHJKLMNPQRSTVWXZ")
    count = 0
    for c in word:
        if c in consonants:
            count = count + 1
            if count > minlen:
                return True
        else:
            count = 0
    return False

def saveSortedListAsTextFile(w_list, keyword, tag):
    fname_base = keyword + '_' + tag + '.txt'
    fpath = Path.cwd() / 'decoded' / keyword
    if not os.path.exists(fpath):
        os.makedirs(fpath)
    fpath_c = fpath / 'checked'
    if not os.path.exists(fpath_c):
        os.makedirs(fpath_c)
    fname = fpath / fname_base
    with open(fname, 'w+', newline ='') as text_file:
        text_file.write("\n".join(str(item) for item in w_list))
        text_file.close();
    return fname

def getListof3Letters(cipher):
    r3list = []
    size = len(cipher) - 2
    if size > 0:
        for i in range(size):
            s = cipher[i:i+3:1]
            r3list.append(s)
    return r3list

def isMatchFound(text, keylist, andAll=False):
    ret = False
    if len(text) > 0 and len(keylist) > 0:
        ret = andAll
        for i in range(len(keylist)):
            index = text.find(keylist[i])
            if not andAll:
                ret = ret or (index >= 0)
            else:
                ret = ret and (index >= 0)
    return ret

# %%
class Reflector:
    """Represents a reflector."""

    def __init__(self, wiring=None, name=None, model=None, date=None, debug=False):
        if wiring != None:
            self.wiring = wiring
        else:
            self.wiring = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
        self.name = name
        self.model = model
        self.date = date
        self.debug = debug

    def __setattr__(self, name, value):
        self.__dict__[name] = value

    def encipher(self, key):
        shift = ord(self.state) - ord("A")
        index = (ord(key) - ord("A")) % 26  # true index
        index = (index + shift) % 26  # actual connector hit
        letter = self.wiring[index]  # rotor letter generated
        out = chr(ord("A") + (ord(letter) - ord("A") + 26 - shift) % 26)  # actual output
        if self.debug:
            print(self.name,' [---] ', self.state,': ', key,' ', out, sep='');
        # return letter
        return out

    def __eq__(self, rotor):
        return self.name == rotor.name
    
    def __str__(self):
        """Pretty display."""
        return """
        Name: {}
        Model: {}
        Date: {}
        Wiring: {}""".format(
            self.name, self.model, self.date, self.wiring
        )

class Rotor:
    """Represents a rotor."""

    def __init__(
        self,
        wiring=None,
        notchs=None,
        name=None,
        model=None,
        date=None,
        state="A",
        ring="A",
        debug=False,
    ):
        """
        Initialization of the rotor.
        """
        if wiring != None:
            self.wiring = wiring
        else:
            self.wiring = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
        self.rwiring = ["0"] * 26
        for i in range(0, len(self.wiring)):
            self.rwiring[ord(self.wiring[i]) - ord("A")] = chr(ord("A") + i)
        if notchs != None:
            self.notchs = notchs
        else:
            self.notchs = ""
        self.name = name
        self.model = model
        self.date = date
        self.state = state
        self.ring = ring
        self.debug = debug

    def __setattr__(self, name, value):
        self.__dict__[name] = value
        if name == "wiring":
            self.rwiring = ["0"] * 26
            for i in range(0, len(self.wiring)):
                self.rwiring[ord(self.wiring[i]) - ord("A")] = chr(ord("A") + i)

    def encipher_right(self, key):
        shift = ord(self.state) - ord(self.ring) + 26
        index = (ord(key) - ord("A")) % 26  # true index
        index = (index + shift) % 26  # actual connector hit
        letter = self.wiring[index]  # rotor letter generated
        out = chr(ord("A") + (ord(letter) - ord("A") + 26 - shift) % 26)  # actual output
        if self.debug:
            print(self.name,' [>>>] ', self.state,': ', key,' ', out, sep='');
        return out

    def encipher_left(self, key):
        shift = ord(self.state) - ord(self.ring) + 26
        index = (ord(key) - ord("A")) % 26
        index = (index + shift) % 26
        # mapped output
        letter = self.rwiring[index]
        out = chr(ord("A") + (ord(letter) - ord("A") + 26 - shift) % 26)
        if self.debug:
            print(self.name,' [<<<] ', self.state,': ', key,' ', out, sep='');
        return out

    def notch(self, offset=1):
        r = chr((ord(self.state) + offset - ord("A")) % 26 + ord("A"))
        if self.debug:
            print(self.name,' [notch] ', self.state,' --> ', r, sep='');
        self.state = r
        notchnext = self.state in self.notchs
        return

    def is_in_turnover_pos(self):
        x = chr((ord(self.state) + 1 - ord("A")) % 26 + ord("A"))
        ret = x in self.notchs
        if self.debug:
            print(self.name,' [turnover] ? = ', ret, ', state = ', x, ', notchs = ', self.notchs, sep='');
        return ret

    def __eq__(self, rotor):
        return self.name == rotor.name

    def __str__(self):
        """
        Pretty display.
        """
        return """
        Name: {}
        Model: {}
        Date: {}
        Wiring: {}
        RWiring: {}
        State: {}""".format(
            self.name, self.model, self.date, self.wiring, ''.join(self.rwiring), self.state
        )


# 1924 Rotors
ROTOR_IC = Rotor(
    wiring="DMTWSILRUYQNKFEJCAZBPGXOHV", name="IC", model="Commercial Enigma A, B", date="1924",)
ROTOR_IIC = Rotor(wiring="HQZGPJTMOBLNCIFDYAWVEUSRKX",name="IIC",model="Commercial Enigma A, B",date="1924",)
ROTOR_IIIC = Rotor(wiring="UQNTLSZFMREHDPXKIBVYGJCWOA",name="IIIC",model="Commercial Enigma A, B",date="1924",)

# German Railway Rotors
ROTOR_GR_I = Rotor(wiring="JGDQOXUSCAMIFRVTPNEWKBLZYH",name="I",model="German Railway (Rocket)",date="7 February 1941",)
ROTOR_GR_II = Rotor(wiring="NTZPSFBOKMWRCJDIVLAEYUXHGQ",name="II",model="German Railway (Rocket)",date="7 February 1941",)
ROTOR_GR_III = Rotor(wiring="JVIUBHTCDYAKEQZPOSGXNRMWFL",name="III",model="German Railway (Rocket)",date="7 February 1941",)
ROTOR_GR_UKW = Reflector(wiring="QYHOGNECVPUZTFDJAXWMKISRBL",name="UTKW",model="German Railway (Rocket)",date="7 February 1941",)
ROTOR_GR_ETW = Rotor(wiring="QWERTZUIOASDFGHJKPYXCVBNML",name="ETW",model="German Railway (Rocket)",date="7 February 1941",)

# Swiss SONDER Rotors
ROTOR_I_SONDER = Rotor(wiring="VEOSIRZUJDQCKGWYPNXAFLTHMB",name="I-SONDER",model="Enigma Sonder",date="February 1939",)
ROTOR_II_SONDER = Rotor(wiring="UEMOATQLSHPKCYFWJZBGVXIDNR",name="II-SONDER",model="Enigma Sonder",date="February 1939",)
ROTOR_III_SONDER = Rotor(wiring="TZHXMBSIPNURJFDKEQVCWGLAOY",name="III-SONDER",model="Enigma Sonder",date="February 1939",)
ROTOR_UKW_SONDER = Reflector(wiring="CIAGSNDRBYTPZFULVHEKOQXWJM",name="UKW-SONDER",model="Enigma Sonder",date="February 1939",)
ROTOR_ETW_SONDER = Rotor(wiring="ABCDEFGHIJKLMNOPQRSTUVWXYZ",name="ETW-SONDER",model="Enigma Sonder",date="February 1939",)

# Enigma K Rotors
ROTOR_I_K = Rotor(wiring="LPGSZMHAEOQKVXRFYBUTNICJDW",notchs="G",name="I-K",model="Enigma K",date="February 1939",)
ROTOR_II_K = Rotor(wiring="SLVGBTFXJQOHEWIRZYAMKPCNDU",notchs="M",name="II-K",model="Enigma K",date="February 1939",)
ROTOR_III_K = Rotor(wiring="CJGDPSHKTURAWZXFMYNQOBVLIE",notchs="V",name="III-K",model="Enigma K",date="February 1939",)
ROTOR_UKW_K = Reflector(wiring="IMETCGFRAYSQBZXWLHKDVUPOJN",name="UKW-K",model="Enigma K",date="February 1939",)
ROTOR_ETW_K = Rotor(wiring="QWERTZUIOASDFGHJKPYXCVBNML",name="ETW-K",model="Enigma K",date="February 1939",)

# Enigma G Rotors, turnover: 'SUVWZABCEFGIKLOPQ', 'STVYZACDFGHKMNQ', 'UWXAEFHKMNR'
ROTOR_I_G = Rotor(wiring="LPGSZMHAEOQKVXRFYBUTNICJDW",notchs="ACDEHIJKMNOQSTWXY",name="I-G",model="Enigma G",date="",)
ROTOR_II_G = Rotor(wiring="SLVGBTFXJQOHEWIRZYAMKPCNDU",notchs="ABDGHIKLNOPSUVY",name="II-G",model="Enigma G",date="",)
ROTOR_III_G = Rotor(wiring="CJGDPSHKTURAWZXFMYNQOBVLIE",notchs="CEFIMNPSUVZ",name="III-G",model="Enigma G",date="",)
ROTOR_UKW_G = Reflector(wiring="IMETCGFRAYSQBZXWLHKDVUPOJN",name="UKW-G",model="Enigma G",date="",)
ROTOR_ETW_G = Rotor(wiring="QWERTZUIOASDFGHJKPYXCVBNML",name="ETW-G",model="Enigma G",date="",)

# Enigma R(ailway) Rotors
ROTOR_I_R = Rotor(wiring="JGDQOXUSCAMIFRVTPNEWKBLZYH",notchs="V",name="I-R",model="Enigma R",date="February 1939",)
ROTOR_II_R = Rotor(wiring="NTZPSFBOKMWRCJDIVLAEYUXHGQ",notchs="M",name="II-R",model="Enigma R",date="February 1939",)
ROTOR_III_R = Rotor(wiring="JVIUBHTCDYAKEQZPOSGXNRMWFL",notchs="G",name="III-R",model="Enigma R",date="February 1939",)
ROTOR_UKW_R = Reflector(wiring="QYHOGNECVPUZTFDJAXWMKISRBL",name="UKW-R",model="Enigma R",date="February 1939",)
ROTOR_ETW_R = Rotor(wiring="QWERTZUIOASDFGHJKPYXCVBNML",name="ETW-R",model="Enigma R",date="February 1939",)

# Swiss K Rotors
ROTOR_I_SK = Rotor(wiring="PEZUOHXSCVFMTBGLRINQJWAYDK",notchs="G",name="I-K",model="Swiss K",date="February 1939",)
ROTOR_II_SK = Rotor(wiring="ZOUESYDKFWPCIQXHMVBLGNJRAT",notchs="M",name="II-K",model="Swiss K",date="February 1939",)
ROTOR_III_SK = Rotor(wiring="EHRVXGAOBQUSIMZFLYNWKTPDJC",notchs="V",name="III-K",model="Swiss K",date="February 1939",)
ROTOR_UKW_SK = Reflector(wiring="IMETCGFRAYSQBZXWLHKDVUPOJN",name="UKW-K",model="Swiss K",date="February 1939",)
ROTOR_ETW_SK = Rotor(wiring="QWERTZUIOASDFGHJKPYXCVBNML",name="ETW-K",model="Swiss K",date="February 1939",)

# Enigma
ROTOR_I = Rotor(wiring="EKMFLGDQVZNTOWYHXUSPAIBRCJ",notchs="R",name="I",model="Enigma 1",date="1930",)
ROTOR_II = Rotor(wiring="AJDKSIRUXBLHWTMCQGZNPYFVOE",notchs="F",name="II",model="Enigma 1",date="1930",)
ROTOR_III = Rotor(wiring="BDFHJLCPRTXVZNYEIWGAKMUSQO",notchs="W",name="III",model="Enigma 1",date="1930",)
ROTOR_IV = Rotor(wiring="ESOVPZJAYQUIRHXLNFTGKDCMWB",notchs="K",name="IV",model="M3 Army",date="December 1938",)
ROTOR_V = Rotor(wiring="VZBRGITYUPSDNHLXAWMJQOFECK",notchs="A",name="V",model="M3 Army",date="December 1938",)
ROTOR_VI = Rotor(wiring="JPGVOUMFYQBENHZRDKASXLICTW",notchs="AN",name="VI",model="M3 & M4 Naval(February 1942)",date="1939",)
ROTOR_VII = Rotor(wiring="NZJHGRCXMYSWBOUFAIVLPEKQDT",notchs="AN",name="VII",model="M3 & M4 Naval(February 1942)",date="1939",)
ROTOR_VIII = Rotor(wiring="FKQHTLXOCBJSPDZRAMEWNIUYGV",notchs="AN",name="VIII",model="M3 & M4 Naval(February 1942)",date="1939",)

# misc & reflectors
ROTOR_Beta = Rotor(
    wiring="LEYJVCNIXWPBQMDRTAKZGFUHOS", name="Beta", model="M4 R2", date="Spring 1941"
)
ROTOR_Gamma = Rotor(
    wiring="FSOKANUERHMBTIYCWLQPZXVGJD", name="Gamma", model="M4 R2", date="Spring 1941"
)
ROTOR_Reflector_A = Reflector(wiring="EJMZALYXVBWFCRQUONTSPIKHGD", name="Reflector A")
ROTOR_Reflector_B = Reflector(wiring="YRUHQSLDPXNGOKMIEBFZCWVJAT", name="Reflector B")
ROTOR_Reflector_C = Reflector(wiring="FVPJIAOYEDRZXWGCTKUQSBNMHL", name="Reflector C")
ROTOR_Reflector_B_Thin = Reflector(
    wiring="ENKQAUYWJICOPBLMDXZVFTHRGS",
    name="Reflector_B_Thin",
    model="M4 R1 (M3 + Thin)",
    date="1940",
)
ROTOR_Reflector_C_Thin = Reflector(
    wiring="RDOBJNTKVEHMLFCWZAXGYIPSUQ",
    name="Reflector_C_Thin",
    model="M4 R1 (M3 + Thin)",
    date="1940",
)
ROTOR_ETW = Rotor(wiring="ABCDEFGHIJKLMNOPQRSTUVWXYZ", name="ETW", model="Enigma 1")

# %%
class Enigma:
    """Represents an Enigma machine.
    Initializes an Enigma machine with these arguments:
    - ref: reflector;
    - r1, r2, r3: rotors;
    - key: initial state of rotors;
    - plus: plugboard settings.
    """

    def __init__(self, ref, r1, r2, r3, key="AAA", plugs="", ring="AAA", notchs="", debug=False):
        """Initialization of the Enigma machine."""
        self.reflector = ref
        self.rotor1 = r1
        self.rotor2 = r2
        self.rotor3 = r3

        self.rotor1.state = key[0]
        self.rotor2.state = key[1]
        self.rotor3.state = key[2]
        self.rotor1.ring = ring[0]
        self.rotor2.ring = ring[1]
        self.rotor3.ring = ring[2]
        if len(notchs) >= 3:
            self.rotor1.notchs = notchs[0]
            self.rotor2.notchs = notchs[1]
            self.rotor3.notchs = notchs[2]
        self.reflector.state = "A"
        self.rotor1.debug = debug
        self.rotor2.debug = debug
        self.rotor3.debug = debug
        self.reflector.debug = debug
        self.debug = debug

        plugboard_settings = [(elem[0], elem[1]) for elem in plugs.split()]

        alpha = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
        alpha_out = [" "] * 26
        for i in range(len(alpha)):
            alpha_out[i] = alpha[i]
        for k, v in plugboard_settings:
            alpha_out[ord(k) - ord("A")] = v
            alpha_out[ord(v) - ord("A")] = k

        try:
            self.transtab = str.maketrans(alpha, "".join(alpha_out))
        except:
            # Python 2
            from string import maketrans

            self.transtab = maketrans(alpha, "".join(alpha_out))

    def encipher(self, plaintext_in):
        """Encrypt 'plaintext_in'."""
        ciphertext = ""
        plaintext_in_upper = plaintext_in.upper()
        plaintext = plaintext_in_upper.translate(self.transtab)
        for c in plaintext:

            # ignore non alphabetic char
            if not c.isalpha():
                ciphertext += c
            else:
                t = self.rotor1.encipher_right(c)
                t = self.rotor2.encipher_right(t)
                t = self.rotor3.encipher_right(t)
                t = self.reflector.encipher(t)
                t = self.rotor3.encipher_left(t)
                t = self.rotor2.encipher_left(t)
                t = self.rotor1.encipher_left(t)
                ciphertext += t

            if self.rotor1.is_in_turnover_pos():
                if self.rotor2.is_in_turnover_pos():
                    self.rotor3.notch()
                self.rotor2.notch()
            self.rotor1.notch()
            if self.debug:
                print('[states] : ', self.rotor1.state, self.rotor2.state, self.rotor3.state, sep='');

        res = ciphertext.translate(self.transtab)

        fres = ""
        for idx, char in enumerate(res):
            if plaintext_in[idx].islower():
                fres += char.lower()
            else:
                fres += char
        return fres
    
    def __str__(self):
        """Pretty display."""
        return """
        Reflector: {}
        Rotor 1: {}
        Rotor 2: {}
        Rotor 3: {}""".format(
            self.reflector, self.rotor1, self.rotor2, self.rotor3
        )

# %%
def msgToCipherByRing(message, ringset, show=False):
    # message: text to encipher
    # ringset: 3 letter ring value to have a cipher ending with
    # return all set of Key-Ring-Cipher tuple with the designated ringset at the end of encoded ciphers
    alphabets = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    keys = []
    for x in alphabets:
        for y in alphabets:
            for z in alphabets:
                keys.append(x + y + z)
    
    ciphers = []
    for j in range(len(keys)):
        engine = Enigma(ROTOR_UKW_K, ROTOR_I_K, ROTOR_II_K, ROTOR_III_K, key=keys[j], ring=ringset, debug=False)
        decoded = engine.encipher(message).upper()
        idx = len(decoded) - 3
        s = decoded[idx:idx+3:1]
        if s == ringset:
            ciphers.append({'Key':keys[j], 'Ring':ringset, 'Message':message, 'Cipher':decoded})
    if len(ciphers) == 0:
        print("There is no Key-Ring-Cipher tuple with the designated ring, ", ringset)
    else:
        print("Key-Ring-Cipher tuple(s) found: ", str(len(ciphers)))
        if show:
            for x in ciphers: print(x)
    return ciphers

def findWordByFixedRing(ciphers, keywords, ringset, show=False):
    # ciphers: encrypted text to look for keywords
    # keywords: list of keywords looking for in ciphers
    # ringset: 3 letter ring value
    # return key-ring-cipher if decrypted text contains keywords by changing key values from AAA to ZZZ
    alphabets = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    keys2 = []
    for x in alphabets:
        for y in alphabets:
            keys2.append(x + y)
            
    outputs = []
    for k in range(len(alphabets)):
        key1 = alphabets[k]
        #print("KEY 1: " + key1)
        for i in range(len(ciphers)):
            for j in range(len(keys2)):
                keyset = key1 + keys2[j]
                engine = Enigma(ROTOR_UKW_K, ROTOR_I_K, ROTOR_II_K, ROTOR_III_K, key=keyset, ring=ringset, debug=False)
                decoded = engine.encipher(ciphers[i])
                if isMatchFound(decoded, keywords):
                    outputs.append({'Key':keyset, 'Ring':ringset, 'Message':decoded, 'Cipher':ciphers[i]})
    if len(outputs) == 0:
        print("There is no Key-Ring-Cipher tuple for search word, ", ringset)
    else:
        print("Key-Ring-Cipher tuple(s) found: ", str(len(outputs)))
        if show:
            for x in outputs: print(x)
    return outputs

def getDecodedCiphersInFiles(ciphers, fixedring=""):
    # ciphers: a list of ciphers
    # ring is set to the last 3 lettets of the given cipher
    # changing key values from AAA to ZZZ, decrypt ciphers and save into file
    alphabets = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    keys2 = []
    for x in alphabets:
        for y in alphabets:
            keys2.append(x + y)
    
    useFixedRing = False
    if len(fixedring) ==3:
        useFixedRing = True

    for k in range(len(alphabets)):
        key1 = alphabets[k]
        print("KEY 1: " + key1)
        for i in range(len(ciphers)):
            s = ciphers[i]
            ringset = s[len(s)-3:]
            if useFixedRing:
                ringset = fixedring.upper()
            parsedWords = []
            decList1 = []
            decList2 = []
            for j in range(len(keys2)):
                keyset = key1 + keys2[j]
                engine = Enigma(ROTOR_UKW_K, ROTOR_I_K, ROTOR_II_K, ROTOR_III_K, key=keyset, ring=ringset, debug=False)
                decoded = engine.encipher(ciphers[i]).upper()
                parsed = ' '.join(wordninja.split(decoded))
                s = str(parsed.count(' ') + 1)
                parsedWords.append(s.rjust(5, '0') + " - " + parsed + " : " + decoded + ": KEY - " + keyset + ": RING - " + ringset)
            if len(parsedWords):
                parsedWords.sort(reverse=False)
                if useFixedRing:
                    f = saveSortedListAsTextFile(parsedWords, ciphers[i] + "_r3_" + ringset, key1)
                else:
                    f = saveSortedListAsTextFile(parsedWords, ciphers[i] + "_r3", key1)
                print('File: ', f, ' saved...')
    return

def decryptCiphersFormatted(ciphers, keys, rings="", plugset=""):
    if len(plugset) == 0:
        print('Plug Board Settings: <none>' + '\n')
    else:
        print('Plug Board Settings: ' + plugset + '\n')

    for i in range(len(ciphers)):
        if len(rings) == 0:
            s = ciphers[i]
            ringset = s[len(s)-3:]
        else:
            ringset = rings
            
        engine = Enigma(ROTOR_UKW_K, ROTOR_I_K, ROTOR_II_K, ROTOR_III_K, key=keys, plugs=plugset, ring=ringset)
        decoded = engine.encipher(ciphers[i]).upper()
        parsed = ' '.join(wordninja.split(decoded))
        print(decoded.rjust(26, ' ') + " - K: " + keyset + " - R: " + ringset + ' -- ' + parsed.ljust(40, ' ') + " - C: " + s)
    return

# %%
findWordByFixedRing(["FEWGDRHDDEEUMFFTEEMJXZR"], ["BANK"], "AAA")
# Out:
# Key-Ring-Cipher tuple(s) found:  4
# [{'Key': 'CVU',
#   'Ring': 'AAA',
#   'Message': 'MKXBFBANKODXXRTMOQTDHQD',
#   'Cipher': 'FEWGDRHDDEEUMFFTEEMJXZR'},
#  {'Key': 'FHG',
#   'Ring': 'AAA',
#   'Message': 'DWQRBZTZOADREBANKQTZQMD',
#   'Cipher': 'FEWGDRHDDEEUMFFTEEMJXZR'},
#  {'Key': 'JQE',
#   'Ring': 'AAA',
#   'Message': 'OUSTGOVPBANKIZMUBMHUVOG',
#   'Cipher': 'FEWGDRHDDEEUMFFTEEMJXZR'},
#  {'Key': 'KXB',
#   'Ring': 'AAA',
#   'Message': 'BANKUPCWXJKZEZPFSVJRLDI',
#   'Cipher': 'FEWGDRHDDEEUMFFTEEMJXZR'}]

# %%
findWordByFixedRing(["FEWGDRHDDEEUMFFTEEMJXZR"], ["BANK"], "AAA")
# Out:
# Key-Ring-Cipher tuple(s) found:  4
# [{'Key': 'CVU',
#   'Ring': 'AAA',
#   'Message': 'MKXBFBANKODXXRTMOQTDHQD',
#   'Cipher': 'FEWGDRHDDEEUMFFTEEMJXZR'},
#  {'Key': 'FHG',
#   'Ring': 'AAA',
#   'Message': 'DWQRBZTZOADREBANKQTZQMD',
#   'Cipher': 'FEWGDRHDDEEUMFFTEEMJXZR'},
#  {'Key': 'JQE',
#   'Ring': 'AAA',
#   'Message': 'OUSTGOVPBANKIZMUBMHUVOG',
#   'Cipher': 'FEWGDRHDDEEUMFFTEEMJXZR'},
#  {'Key': 'KXB',
#   'Ring': 'AAA',
#   'Message': 'BANKUPCWXJKZEZPFSVJRLDI',
#   'Cipher': 'FEWGDRHDDEEUMFFTEEMJXZR'}]

# %%
ring = "XZR"
msg = "OUSTGOVPBANKIZMUBMHUVOG"
msgToCipherByRing(msg, ring, show=True)
# Out:
# Key-Ring-Cipher tuple(s) found:  2
# {'Key': 'BUX', 'Ring': 'XZR', 'Message': 'OUSTGOVPBANKIZMUBMHUVOG', 'Cipher': 'CJJCQGOVVIYVEMBVVDDPXZR'}
# {'Key': 'GPV', 'Ring': 'XZR', 'Message': 'OUSTGOVPBANKIZMUBMHUVOG', 'Cipher': 'FEWGDRHDDEEUMFFTEEMJXZR'}
# [{'Key': 'BUX',
#   'Ring': 'XZR',
#   'Message': 'OUSTGOVPBANKIZMUBMHUVOG',
#   'Cipher': 'CJJCQGOVVIYVEMBVVDDPXZR'},
#  {'Key': 'GPV',
#   'Ring': 'XZR',
#   'Message': 'OUSTGOVPBANKIZMUBMHUVOG',
#   'Cipher': 'FEWGDRHDDEEUMFFTEEMJXZR'}]

# %%
ring = "XZR"
msg = "HELLOWORLD"
msgToCipherByRing(msg, ring, show=True)
# Out:
# There is no Key-Ring-Cipher tuple with the designated ring,  XZR
# []

# %%
ring = "XXX"
msg = "HELLOWORLD"
msgToCipherByRing(msg, ring, show=True)
# Out:
# Key-Ring-Cipher tuple(s) found:  2
# {'Key': 'CFY', 'Ring': 'XXX', 'Message': 'HELLOWORLD', 'Cipher': 'RBTUTBUXXX'}
# {'Key': 'HDO', 'Ring': 'XXX', 'Message': 'HELLOWORLD', 'Cipher': 'WXMARVWXXX'}
# [{'Key': 'CFY',
#   'Ring': 'XXX',
#   'Message': 'HELLOWORLD',
#   'Cipher': 'RBTUTBUXXX'},
#  {'Key': 'HDO',
#   'Ring': 'XXX',
#   'Message': 'HELLOWORLD',
#   'Cipher': 'WXMARVWXXX'}]

# %%
# set RING to the fixedring
getDecodedCiphersInFiles(["helloworld"], fixedring="SRH")
# Out:
# KEY 1: A
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_A.txt  saved...
# KEY 1: B
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_B.txt  saved...
# KEY 1: C
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_C.txt  saved...
# KEY 1: D
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_D.txt  saved...
# KEY 1: E
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_E.txt  saved...
# KEY 1: F
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_F.txt  saved...
# KEY 1: G
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_G.txt  saved...
# KEY 1: H
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_H.txt  saved...
# KEY 1: I
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_I.txt  saved...
# KEY 1: J
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_J.txt  saved...
# KEY 1: K
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_K.txt  saved...
# KEY 1: L
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_L.txt  saved...
# KEY 1: M
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_M.txt  saved...
# KEY 1: N
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_N.txt  saved...
# KEY 1: O
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_O.txt  saved...
# KEY 1: P
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_P.txt  saved...
# KEY 1: Q
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_Q.txt  saved...
# KEY 1: R
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_R.txt  saved...
# KEY 1: S
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_S.txt  saved...
# KEY 1: T
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_T.txt  saved...
# KEY 1: U
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_U.txt  saved...
# KEY 1: V
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_V.txt  saved...
# KEY 1: W
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_W.txt  saved...
# KEY 1: X
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_X.txt  saved...
# KEY 1: Y
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_Y.txt  saved...
# KEY 1: Z
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3_SRH\helloworld_r3_SRH_Z.txt  saved...

# %%
# set RING to last 3 letters (fixedring="")
getDecodedCiphersInFiles(["helloworld"])
# Out:
# KEY 1: A
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_A.txt  saved...
# KEY 1: B
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_B.txt  saved...
# KEY 1: C
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_C.txt  saved...
# KEY 1: D
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_D.txt  saved...
# KEY 1: E
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_E.txt  saved...
# KEY 1: F
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_F.txt  saved...
# KEY 1: G
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_G.txt  saved...
# KEY 1: H
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_H.txt  saved...
# KEY 1: I
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_I.txt  saved...
# KEY 1: J
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_J.txt  saved...
# KEY 1: K
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_K.txt  saved...
# KEY 1: L
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_L.txt  saved...
# KEY 1: M
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_M.txt  saved...
# KEY 1: N
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_N.txt  saved...
# KEY 1: O
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_O.txt  saved...
# KEY 1: P
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_P.txt  saved...
# KEY 1: Q
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_Q.txt  saved...
# KEY 1: R
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_R.txt  saved...
# KEY 1: S
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_S.txt  saved...
# KEY 1: T
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_T.txt  saved...
# KEY 1: U
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_U.txt  saved...
# KEY 1: V
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_V.txt  saved...
# KEY 1: W
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_W.txt  saved...
# KEY 1: X
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_X.txt  saved...
# KEY 1: Y
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_Y.txt  saved...
# KEY 1: Z
# File:  G:\DeepLearning\codes\goldbar\decoded\helloworld_r3\helloworld_r3_Z.txt  saved...

# %%
engine = Enigma(ROTOR_UKW_K, ROTOR_I_K, ROTOR_II_K, ROTOR_III_K, key="SNR", ring="XZX")
#print(engine)
secret = engine.encipher("OUSTGOVPBANKIZMUBMHUVOG")
print(secret)
#
engine = Enigma(ROTOR_UKW_K, ROTOR_I_K, ROTOR_II_K, ROTOR_III_K, key="SNR", ring="XZX")
text = engine.encipher(secret)
print(text)
# Out:
# SFUUKCULZUYSMHEJCKCBXZX
# OUSTGOVPBANKIZMUBMHUVOG

# %%
keyset = "GPV"
ringset = "AAA" #"XZR"
text = "ABCDEFGHIJKLMNOPQRSTUVWXYZ" #"OUSTGOVPBANKIZMUBMHUVOG"
#
engine = Enigma(ROTOR_UKW_K, ROTOR_I_K, ROTOR_II_K, ROTOR_III_K, key=keyset, ring=ringset)
secret = engine.encipher(text)
print(text)
print(secret)
#
engine = Enigma(ROTOR_UKW_K, ROTOR_I_K, ROTOR_II_K, ROTOR_III_K, key=keyset, ring=ringset)
text = engine.encipher(secret)
print(text)
# Out:
# ABCDEFGHIJKLMNOPQRSTUVWXYZ
# NSDZXUXNAOGSDGKLHEBBRIZMBI
# ABCDEFGHIJKLMNOPQRSTUVWXYZ

# %%
cipher_shorts = [
    "FEWGDRHDDEEUMFFTEEMJXZR",#JQE
    "UGMNCBXCFLDEY", #SQE
    "HLMTAHGBGFNIV",#upside down-----
    "MLMTAHGBGFNIV",
    "ZUQUPNZN",
    "ABRYCTUGVZXUPB",
    "MVERZRLQDBHQ",
    "GKJFHYXODIE",
    "UGMNCBXCRLDEY",
    "UGMNCBXCFLDFY",
    "HFXPCQYZVATXAWIZPVE",#upside down-----
    "JKGFIJPMCWSAEK",#top down---
    "JKGFIJPMCWSAFK",
    "SKCDKJCDJCYQSZKTZJPXPWIRN",
    "MQOLCSJTLGAJOKBSSBOMUPCE",
    "RHZVIYQIYSXVNQXQWIOVWPJO",#top down---
    "YQHUDTABGALLOWLS",
    "VIOHIKNNGUAB",
    "KOWVRSRWTMLDH",
]

keyset = "IWA"
decryptCiphersFormatted(cipher_shorts, keyset)

print()
plug = "YQ HU DT AB GA LL OW LS"
decryptCiphersFormatted(cipher_shorts, keyset, plugset=plug)
# Out:
# Plug Board Settings: <none>
#
#    WOMTQXTGZSNMKBPJNCXZEFP - K: IWA - R: XZR -- WO MT QX TGZ SN MK BP JN CX ZEF P        - C: FEWGDRHDDEEUMFFTEEMJXZR
#              NHYJEOPEMACLM - K: IWA - R: DEY -- N HY JEO PE MAC LM                       - C: UGMNCBXCFLDEY
#              XXOLZZENTTCJW - K: IWA - R: NIV -- XX O LZ ZEN TTC J W                      - C: HLMTAHGBGFNIV
#              UXOLZZENTTCJW - K: IWA - R: NIV -- U XO LZ ZEN TTC J W                      - C: MLMTAHGBGFNIV
#                   NBLGWIJF - K: IWA - R: NZN -- NBL GW IJ F                              - C: ZUQUPNZN
#             JPOHUYMKEIILBJ - K: IWA - R: UPB -- J PO HUY M KEI IL BJ                     - C: ABRYCTUGVZXUPB
#               IHVZQPEXEPKS - K: IWA - R: BHQ -- I HV Z QP EXE PK S                       - C: MVERZRLQDBHQ
#                FJRQZISWQEZ - K: IWA - R: DIE -- F JR Q Z IS WQ EZ                        - C: GKJFHYXODIE
#              NHYJEOPEQACLM - K: IWA - R: DEY -- N HY JEO PE QA CL M                      - C: UGMNCBXCRLDEY
#              EWVFRUMLUHQMB - K: IWA - R: DFY -- EW VFR UML U HQ MB                       - C: UGMNCBXCFLDFY
#        ITBKLVKDQCIZDADAVKG - K: IWA - R: PVE -- IT BK LV K D QC I ZD ADAV KG             - C: HFXPCQYZVATXAWIZPVE
#             GQCBYTNDYCDXAT - K: IWA - R: AEK -- GQ C BY TN DY CD X AT                    - C: JKGFIJPMCWSAEK
#             LQQBVIHQVPTRZM - K: IWA - R: AFK -- L QQ BVI HQ VP TR ZM                     - C: JKGFIJPMCWSAFK
#  ZRNYYSZAGESCXVFDWDFCQYXWY - K: IWA - R: IRN -- Z RN YY SZ AGES CX VFD WDF CQ Y X WY     - C: SKCDKJCDJCYQSZKTZJPXPWIRN
#   KKXMNCNEYVRUXTWWXDKPHLBB - K: IWA - R: PCE -- KK XM NC NE YVR UX T WW XD KPH LB B      - C: MQOLCSJTLGAJOKBSSBOMUPCE
#   UZAGAOWNGFPKJYLYORMKTMAJ - K: IWA - R: PJO -- U ZAG A OWN G FPK JY LY OR MKT MAJ       - C: RHZVIYQIYSXVNQXQWIOVWPJO
#           BYZOLBIDQZKBAUBI - K: IWA - R: WLS -- BY ZO L BID Q Z K BAU BI                 - C: YQHUDTABGALLOWLS
#               QHHTZWKOCWKR - K: IWA - R: UAB -- QH HT ZW KO CW KR                        - C: VIOHIKNNGUAB
#              OZTDDCYHLUEFR - K: IWA - R: LDH -- OZ TDD CY HL UE FR                       - C: KOWVRSRWTMLDH
#
# Plug Board Settings: YQ HU DT AB GA LL OW LS
#
#    OWZAUXQSQLNLKAPUNCXZEFP - K: IWA - R: XZR -- OW Z AUX Q SQL NL KAPU NC X ZEF P        - C: FEWGDRHDDEEUMFFTEEMJXZR
#              VMQJEXPEMVNSZ - K: IWA - R: DEY -- VM Q J EXP EM V N SZ                     - C: UGMNCBXCFLDEY
#              MEWCSWXCNDCJO - K: IWA - R: NIV -- MEW C SW XC ND C JO                      - C: HLMTAHGBGFNIV
#              HEWCSWXCNDCJO - K: IWA - R: NIV -- HE WC SW XC ND C JO                      - C: MLMTAHGBGFNIV
#                   NRLSOIJF - K: IWA - R: NZN -- NRL SO IJ F                              - C: ZUQUPNZN
#             RKWGHFDIEIILAD - K: IWA - R: UPB -- RK WG HF DIE II LAD                      - C: ABRYCTUGVZXUPB
#               IUVZYPCVIWCH - K: IWA - R: BHQ -- I UV ZY PC VI W CH                       - C: MVERZRLQDBHQ
#                SJRYTSLWGEZ - K: IWA - R: DIE -- SJ RY TS LW G EZ                         - C: GKJFHYXODIE
#              VMQJEXPEYVNSZ - K: IWA - R: DEY -- VM Q J EX PEY V N SZ                     - C: UGMNCBXCRLDEY
#              IPVFRCMSHRMME - K: IWA - R: DFY -- IPV FR CMS HR MME                        - C: UGMNCBXCFLDFY
#        RDAKSWATYNEZHJTGVKA - K: IWA - R: PVE -- RD A KSW A TYNE ZH JTG VKA               - C: HFXPCQYZVATXAWIZPVE
#             AYVAQDNTQAVYGD - K: IWA - R: AEK -- AY VA QD NT QA VY GD                     - C: JKGFIJPMCWSAEK
#             SYXAVIUYVSJOZM - K: IWA - R: AFK -- SY XAVI U Y VS JO ZM                     - C: JKGFIJPMCWSAFK
#  ERNRQLZMAEAKPVFDOTFCYNXOQ - K: IWA - R: IRN -- ERN R Q LZ MAE A KP VF DOT F CYN XO Q    - C: SKCDKJCDJCYQSZKTZJPXPWIRN
#   KMQWNMNKNJEHNDVUFSAPHSAA - K: IWA - R: PCE -- KM Q W NM NK NJE HN DVU FSA PH S A A     - C: MQOLCSJTLGAJOKBSSBOMUPCE
#   HOGAGHJNUPPKJYSYORCKFMGR - K: IWA - R: PJO -- HOG A GH JN UP PK JY SY OR CK FM GR      - C: RHZVIYQIYSXVNQXQWIOVWPJO
#           GYIRHEUVFNZDXFXK - K: IWA - R: WLS -- GYI R HE UVF NZ DX FX K                  - C: YQHUDTABGALLOWLS
#               YUJYZOKWVPUS - K: IWA - R: UAB -- YU J YZ OKW VP US                        - C: VIOHIKNNGUAB
#              WJETTQQEXHYAZ - K: IWA - R: LDH -- W JETT QQ EX H YAZ                       - C: KOWVRSRWTMLDH

# %%
# notice that the maximum length of short ciphers is 25, less than 1 compared to the alphabets A to Z
cipher_shorts = [
    #"FEWGDRHDDEEUMFFTEEMJXZR",#JQE
    #"UGMNCBXCFLDEY", #SQE
    #"HLMTAHGBGFNIV",#upside down-----
    #"MLMTAHGBGFNIV",
    #"ZUQUPNZN",
    #"ABRYCTUGVZXUPB",
    #"MVERZRLQDBHQ",
    #"GKJFHYXODIE",
    #"UGMNCBXCRLDEY",
    #"UGMNCBXCFLDFY",
    #"HFXPCQYZVATXAWIZPVE",#upside down-----
    #"JKGFIJPMCWSAEK",#top down---
    #"SKCDKJCDJCYQSZKTZJPXPWIRN",
    #"MQOLCSJTLGAJOKBSSBOMUPCE",
    #"RHZVIYQIYSXVNQXQWIOVWPJO",#top down---
    #"YQHUDTABGALLOWLS",
    #"VIOHIKNNGUAB",
    #"KOWVRSRWTMLDH",
    #"XLYPISNANIRUSFTFWMIY",
    #
    #"YQVIOHIKNNGUABLS", # YQHUDTABGALLOWLS xor VIOHIKNNGUAB
    #"IZMUBMHU", # from OUSTGOVPBANK 'IZMUBMHU' VOG, double coding?
    #"UHMBUMZI", # reverse of IZMUBMHU
    #"JDSRKJSSBRVXVYHIQUL" # AMEND JDSRKJSSBRVXVYHIQUL from MQOLCSJTLGAJOKBSSBOMUPCE
    #"ALTYKDBJZ" # USE ALTYKDBJZ GOV DVDULIDUD from MQOLCSJTLGAJOKBSSBOMUPCE
    #"DVDULIDUD" # USE ALTYKDBJZ GOV DVDULIDUD from MQOLCSJTLGAJOKBSSBOMUPCE
    #"NLBRHQEM" # USE ACC NO NLBRHQEM from KOWVRSRWTMLDH
    #"VIOHIKNNGIWA" # change from VIOHIKNNGUAB with XOR ID IWA from ZUQUPNZN
    #"WXDYFXJFEXCBNS" # BAY WXDYFXJFEXCBNS TACKY LOT from SKCDKJCDJCYQSZKTZJPXPWIRN with Ring EFG
    #"WXDYFXJFEXCBN" # BAY WXDYFXJFEXCBN STACKY LOT from SKCDKJCDJCYQSZKTZJPXPWIRN with Ring EFG
    #"JDSIIEZKIUTARFHIQUL" # AMEND JDSIIEZKIUTARFHIQUL from MQOLCSJTLGAJOKBSSBOMUPCE with Ring AAA
    #"AEOUYBWQCUXKPQLTOGZRV" # GOV AEOUYBWQCUXKPQLTOGZRV from MQOLCSJTLGAJOKBSSBOMUPCE with Ring AAA
    #"ABRYCTUGVZXIWA", # EXOR ID IWA from ZUQUPNZN with Ring of FWT
    #"TWGYXTOAEWMYSXFH", # "QUIZ" TWGYXTOAEWMYSXFH from XLYPISNANIRUSFTFWMIY
    #"TWGYX", # "QUIZ" TWGYX TO AEWMYSXFH from XLYPISNANIRUSFTFWMIY
    #"AEWMYSXFH", # "QUIZ" TWGYX TO AEWMYSXFH from XLYPISNANIRUSFTFWMIY
    #"WDGZCPJOAPOCSXKBD", # "MSG" WDGZCPJOAPOCSXKBD from XLYPISNANIRUSFTFWMIY
    #"LFVSSHCNYHIO", # GAME LFVSSHCNYHIO ROOM from XLYPISNANIRUSFTFWMIY
    #"KDXIGIM", # KDXIGIM (FOR KDXIGIM OF WXAUTSM) from HFXPCQYZVATXAWIZPVE
    #"WXAUTSM", # WXAUTSM (FOR KDXIGIM OF WXAUTSM) from HFXPCQYZVATXAWIZPVE
    #"UIFEKSFGVWTZ", # KDXIGIM (US BERGE UIFEKSFGVWTZ) from HFXPCQYZVATXAWIZPVE
    #"YDZXUFCPC", # US BERGE GOV YDZXUFCPC from UIFEKSFGVWTZ (UIF12)
    #"CUFDLPT", # US BERGE ABIDE CUFDLPT from UIFEKSFGVWTZ (UIF12)
    #"NOCNNTTCLASES", # PAY NOCNNTTCLASES IF PASOLI from RHZVIYQIYSXVNQXQWIOVWPJO
    #"CNNTTCLASES", # PAY NO CNNTTCLASES IF PASOLI from RHZVIYQIYSXVNQXQWIOVWPJO
    #"PASOLI", # PAY NO CNNTTCLASES IF PASOLI from RHZVIYQIYSXVNQXQWIOVWPJO
    #"QIAHUNOQ", # KEY QIAHUNOQ UP from NOCNNTTCLASES of RHZVIYQIYSXVNQXQWIOVWPJO
    #"AAKAFFEYQ", # US AAKAFFEYQ UP from NOCNNTTCLASES of RHZVIYQIYSXVNQXQWIOVWPJO
    #"DBLTKA", # GOV DBLTKA from AAKAFFEYQ of NOCNNTTCLASES
    #"WBDGBZW", # BY WBDGBZW RIP ON from ABRYCTUGVZXUPB
    #"BWKOSOWFC", # KEY VS BWKOSOWFC from ABRYCTUGVZXUPB
    #"FCMULUDATG", # BY FCMULUDATG TO from ABRYCTUGVZXUPB
    #"SPIBLDZCQ", # REPAY SPIBLDZCQ from ABRYCTUGVZXUPB
    #"LENIELCLRHB", # GOV LENIELCLRHB TO from ABRYCTUGVZXUPB
    #"YQGKJFHYXODIELS", # YQ GKJFHYXODIE LS from MVERZRLQDBHQ GKJFHYXODIE
    #"LXGTPDIDAIJGBMWVP", # BY PAY QIN LXGTPDIDAIJGBMWVP from SKCDKJCDJCYQSZKTZJPXPWIRN with IRN
    #"LFDZQDIDAIJGBMWVP", # BY PAY QIN LFDZQDIDAIJGBMWVP from SKCDKJCDJCYQSZKTZJPXPWIRN with EFG
    #"DSPYOZ", # IF USE DSPYOZ from GKJFHYXODIE
    "LUQXGUMS", # LUQXGUMS SIGCO from UGMNCBXCFLDEY with AZH
    "THEIWKSRQT", # WAR THEIWKSRQT from UGMNCBXCFLDEY with AZH
    "FFYAWQVXT", # GOLD FFYAWQVXT from UGMNCBXCFLDEY with AZH
    "DIROSDOLI", # CASH DIROSDOLI from UGMNCBXCFLDEY with AZH
]

# start with 'H', do 'G' at the end since it rotates the second rotor
alphabets = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
alpha1 = alphabets
alpha2 = alphabets
alpha3 = alphabets
keys2 = []
for x in alpha2:
    for y in alpha3:
        keys2.append(x + y)

for k in range(len(alpha1)):
    key1 = alpha1[k]
    print("KEY 1: " + key1)
    for i in range(len(cipher_shorts)):
        s = cipher_shorts[i]
        ringset = s[len(s)-3:]
        parsedWords = []
        decList1 = []
        decList2 = []
        for j in range(len(keys2)):
            keyset = key1 + keys2[j]
            #
            engine = Enigma(ROTOR_UKW_K, ROTOR_I_K, ROTOR_II_K, ROTOR_III_K, key=keyset, ring=ringset, debug=False)
            decoded = engine.encipher(cipher_shorts[i]).upper()
            parsed = ' '.join(wordninja.split(decoded))
            s = str(parsed.count(' ') + 1)
            parsedWords.append(s.rjust(5, '0') + " - " + parsed + " : " + decoded + ": KEY - " + keyset + ": RING - " + ringset)
        #
        if len(parsedWords):
            parsedWords.sort(reverse=False)
            saveSortedListAsTextFile(parsedWords, cipher_shorts[i] + "_123_ninja_r3", key1)
# Out:
# KEY 1: A
# KEY 1: B
# KEY 1: C
# KEY 1: D
# KEY 1: E
# KEY 1: F
# KEY 1: G
# KEY 1: H
# KEY 1: I
# KEY 1: J
# KEY 1: K
# KEY 1: L
# KEY 1: M
# KEY 1: N
# KEY 1: O
# KEY 1: P
# KEY 1: Q
# KEY 1: R
# KEY 1: S
# KEY 1: T
# KEY 1: U
# KEY 1: V
# KEY 1: W
# KEY 1: X
# KEY 1: Y
# KEY 1: Z

# %%
# 8/31/2024 - use specific Ring for decipherment instead of R3 letters
# notice that the maximum length of short ciphers is 25, less than 1 compared to the alphabets A to Z
cipher_shorts = [
    #"FEWGDRHDDEEUMFFTEEMJXZR",#JQE
    #"UGMNCBXCFLDEY", #SQE
    #"HLMTAHGBGFNIV",#upside down-----
    #"MLMTAHGBGFNIV",
    #"ZUQUPNZN",
    #"ABRYCTUGVZXUPB",
    #"MVERZRLQDBHQ",
    #"GKJFHYXODIE",
    "UGMNCBXCRLDEY",
    #"UGMNCBXCFLDFY",
    #"HFXPCQYZVATXAWIZPVE",#upside down-----
    #"JKGFIJPMCWSAEK",#top down---
    #"JKGFIJPMCWSAFK",
    #"SKCDKJCDJCYQSZKTZJPXPWIRN",
    #"MQOLCSJTLGAJOKBSSBOMUPCE",
    #"RHZVIYQIYSXVNQXQWIOVWPJO",#top down---
    #"YQHUDTABGALLOWLS",
    #"VIOHIKNNGUAB",
    #"KOWVRSRWTMLDH",
    #"XLYPISNANIRUSFTFWMIY",
    #
    #"YQVIOHIKNNGUABLS", # YQHUDTABGALLOWLS xor VIOHIKNNGUAB
    #"IZMUBMHU", # from OUSTGOVPBANK 'IZMUBMHU' VOG, double coding?
    #"UHMBUMZI", # reverse of IZMUBMHU
    #"JKGFIJPMCWSAEK", # with FWT from CONTACT FWT DEWVRY (YQVIOHIKNNGUABLS)
    #"ZUQUPNZN", # with FWT from CONTACT FWT DEWVRY (YQVIOHIKNNGUABLS)
    #"YQGKJFHYXODIELS", # YQ GKJFHYXODIE LS from MVERZRLQDBHQ GKJFHYXODIE
]

# start with 'H', do 'G' at the end since it rotates the second rotor
alphabets = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
alpha1 = alphabets
alpha2 = alphabets
alpha3 = alphabets
keys2 = []
for x in alpha2:
    for y in alpha3:
        keys2.append(x + y)

#fixedring = "SRH" # from TWO MSG XOR 'SRH'
#fixedring = "FWT" # from CONTACT FWT DEWVRY (YQVIOHIKNNGUABLS)
#fixedring = "EFG" # from ACT DMZ EFG SIG CT (JKGFIJPMCWSAEK)
#fixedring = "GMH" # from PIER GMH OVAL SAD (WXDYFXJFEXCBNS)
#fixedring = "ZZV" # from BLOBS NIEM RD ZZV (WXDYFXJFEXCBNS)
#fixedring = "BEW" # from ABV BEW JR FF MAM (UGMNCBXCRLDEY)
fixedring = "AZH" # from AZH LATE TOLD (GKJFHYXODIE > GKJFHYXOIWA)

for k in range(len(alpha1)):
    key1 = alpha1[k]
    print("KEY 1: " + key1)
    for i in range(len(cipher_shorts)):
        s = cipher_shorts[i]
        ringset = fixedring #s[len(s)-3:]
        parsedWords = []
        decList1 = []
        decList2 = []
        for j in range(len(keys2)):
            keyset = key1 + keys2[j]
            #
            engine = Enigma(ROTOR_UKW_K, ROTOR_I_K, ROTOR_II_K, ROTOR_III_K, key=keyset, ring=ringset, debug=False)
            decoded = engine.encipher(cipher_shorts[i]).upper()
            parsed = ' '.join(wordninja.split(decoded))
            s = str(parsed.count(' ') + 1)
            parsedWords.append(s.rjust(5, '0') + " - " + parsed + " : " + decoded + ": KEY - " + keyset + ": RING - " + ringset)
        #
        if len(parsedWords):
            parsedWords.sort(reverse=False)
            saveSortedListAsTextFile(parsedWords, cipher_shorts[i] + "_123_ninja_r3_" + fixedring, key1)
# Out:
# KEY 1: A
# KEY 1: B
# KEY 1: C
# KEY 1: D
# KEY 1: E
# KEY 1: F
# KEY 1: G
# KEY 1: H
# KEY 1: I
# KEY 1: J
# KEY 1: K
# KEY 1: L
# KEY 1: M
# KEY 1: N
# KEY 1: O
# KEY 1: P
# KEY 1: Q
# KEY 1: R
# KEY 1: S
# KEY 1: T
# KEY 1: U
# KEY 1: V
# KEY 1: W
# KEY 1: X
# KEY 1: Y
# KEY 1: Z

# %%
# 8/27/2024 - use 3 letters for rings out of a given cipher and find exact matches
# notice that the maximum length of short ciphers is 25, less than 1 compared to the alphabets A to Z
cipher_shorts = [
    #"FEWGDRHDDEEUMFFTEEMJXZR",#JQE
    #"UGMNCBXCFLDEY", #SQE
    #"HLMTAHGBGFNIV",#upside down-----
    #"ZUQUPNZN",
    #"ABRYCTUGVZXUPB",
    #"MVERZRLQDBHQ",
    #"GKJFHYXODIE",
    #"UGMNCBXCRLDEY",
    #"UGMNCBXCFLDFY",
    "HFXPCQYZVATXAWIZPVE",#upside down-----
    #"JKGFIJPMCWSAEK",#top down---
    #"SKCDKJCDJCYQSZKTZJPXPWIRN",
    #"MQOLCSJTLGAJOKBSSBOMUPCE",
    #"RHZVIYQIYSXVNQXQWIOVWPJO",#top down---
    #"YQHUDTABGALLOWLS",
    #"VIOHIKNNGUAB",
    #"KOWVRSRWTMLDH",
]
keywords = [
    #"KEY",
    #"BANK", #FEWGDRHDDEEUMFFTEEMJXZR
    #"OUSTGOV" #FEWGDRHDDEEUMFFTEEMJXZR
    #"TWOMSG", #MVERZRLQDBHQ
    #"OKFLY", #MVERZRLQDBHQ
    #"HEACTIN", #MVERZRLQDBHQ
    #"EXPMOAUG", #MQOLCSJTLGAJOKBSSBOMUPCE
    #"ALLOR", #ZUQUPNZN
    #"ACCNO", #KOWVRSRWTMLDH
    #"QUERY",
    #"USA",
    #"TXNAME",
    #"QUARZ",
    #"LINDE", #HLMTAHGBGFNIV
    #"SIGCO",
    "USBERGE",
]
# start with 'H', do 'G' at the end since it rotates the second rotor
alphabets = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
alpha1 = alphabets
alpha2 = alphabets
alpha3 = alphabets
keys2 = []
for x in alpha2:
    for y in alpha3:
        keys2.append(x + y)

for kk in range(len(alpha1)):
    key1 = alpha1[kk]
    print("KEY 1: " + key1)
    for i in range(len(cipher_shorts)):
        # forward
        print("--- Forward ---")
        ringlist = getListof3Letters(cipher_shorts[i])
        if kk == 0: print(ringlist)
        for k in range(len(ringlist)):
            for j in range(len(keys2)):
                keyset = key1 + keys2[j]
                engine = Enigma(ROTOR_UKW_K, ROTOR_I_K, ROTOR_II_K, ROTOR_III_K, key=keyset, ring=ringlist[k], debug=False)
                decoded = engine.encipher(cipher_shorts[i]).upper()
                if isMatchFound(decoded, keywords, andAll=False):
                    t1 = cipher_shorts[i] + ": " + decoded + ' -key- ' + keyset + ' -ring- ' + ringlist[k]
                    print(t1, sep="")
        # reverse
        print("--- Reverse ---")
        s = cipher_shorts[i]
        ringlist = getListof3Letters(s[::-1])
        if kk == 0: print(ringlist)
        for k in range(len(ringlist)):
            for j in range(len(keys2)):
                keyset = key1 + keys2[j]
                engine = Enigma(ROTOR_UKW_K, ROTOR_I_K, ROTOR_II_K, ROTOR_III_K, key=keyset, ring=ringlist[k], debug=False)
                decoded = engine.encipher(cipher_shorts[i]).upper()
                if isMatchFound(decoded, keywords, andAll=False):
                    t1 = cipher_shorts[i] + ": " + decoded + ' -key- ' + keyset + ' -ring- ' + ringlist[k]
                    print(t1, sep="")
# Out:
# KEY 1: A
# --- Forward ---
# ['HFX', 'FXP', 'XPC', 'PCQ', 'CQY', 'QYZ', 'YZV', 'ZVA', 'VAT', 'ATX', 'TXA', 'XAW', 'AWI', 'WIZ', 'IZP', 'ZPV', 'PVE']
# --- Reverse ---
# ['EVP', 'VPZ', 'PZI', 'ZIW', 'IWA', 'WAX', 'AXT', 'XTA', 'TAV', 'AVZ', 'VZY', 'ZYQ', 'YQC', 'QCP', 'CPX', 'PXF', 'XFH']
# KEY 1: B
# --- Forward ---
# --- Reverse ---
# KEY 1: C
# --- Forward ---
# --- Reverse ---
# KEY 1: D
# --- Forward ---
# --- Reverse ---
# KEY 1: E
# --- Forward ---
# --- Reverse ---
# KEY 1: F
# --- Forward ---
# --- Reverse ---
# KEY 1: G
# --- Forward ---
# --- Reverse ---
# KEY 1: H
# --- Forward ---
# --- Reverse ---
# KEY 1: I
# --- Forward ---
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWTZ -key- IKO -ring- TXA
# --- Reverse ---
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWTZ -key- INJ -ring- TAV
# KEY 1: J
# --- Forward ---
# --- Reverse ---
# KEY 1: K
# --- Forward ---
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWTZ -key- KNH -ring- VAT
# --- Reverse ---
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWTZ -key- KCN -ring- VPZ
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWTZ -key- KMM -ring- VZY
# KEY 1: L
# --- Forward ---
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWTZ -key- LVN -ring- WIZ
# --- Reverse ---
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWTZ -key- LNL -ring- WAX
# KEY 1: M
# --- Forward ---
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWTZ -key- MCQ -ring- XPC
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWTZ -key- MNK -ring- XAW
# --- Reverse ---
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWTZ -key- MGO -ring- XTA
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWTZ -key- MSV -ring- XFH
# KEY 1: N
# --- Forward ---
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWTZ -key- NMJ -ring- YZV
# --- Reverse ---
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWTZ -key- NDQ -ring- YQC
# KEY 1: O
# --- Forward ---
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWTG -key- OIO -ring- ZVA
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWTG -key- OCJ -ring- ZPV
# --- Reverse ---
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWTG -key- OVK -ring- ZIW
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWTV -key- OLE -ring- ZYQ
# KEY 1: P
# --- Forward ---
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWPG -key- PGL -ring- ATX
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWPG -key- PJW -ring- AWI
# --- Reverse ---
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWPG -key- PKH -ring- AXT
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWPG -key- PIN -ring- AVZ
# KEY 1: Q
# --- Forward ---
# --- Reverse ---
# KEY 1: R
# --- Forward ---
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGGXPG -key- RDM -ring- CQY
# --- Reverse ---
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGGXPG -key- RCL -ring- CPX
# KEY 1: S
# --- Forward ---
# --- Reverse ---
# KEY 1: T
# --- Forward ---
# --- Reverse ---
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSJTGXPG -key- TID -ring- EVP
# KEY 1: U
# --- Forward ---
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKTJTGXPG -key- UKD -ring- FXP
# --- Reverse ---
# KEY 1: V
# --- Forward ---
# --- Reverse ---
# KEY 1: W
# --- Forward ---
# HFXPCQYZVATXAWIZPVE: USBERGEUIFNWTJTGXPG -key- WSL -ring- HFX
# --- Reverse ---
# KEY 1: X
# --- Forward ---
# HFXPCQYZVATXAWIZPVE: USBERGEUIZNWTJTGXPG -key- XMD -ring- IZP
# --- Reverse ---
# HFXPCQYZVATXAWIZPVE: USBERGEUIZNWTJTGXPG -key- XJO -ring- IWA
# KEY 1: Y
# --- Forward ---
# --- Reverse ---
# KEY 1: Z
# --- Forward ---
# --- Reverse ---

# %%
cipher_shorts = [
    #"FEWGDRHDDEEUMFFTEEMJXZR",#JQE
    #"UGMNCBXCFLDEY", #SQE
    #"HLMTAHGBGFNIV",#upside down-----
    #"MLMTAHGBGFNIV",
    #"ZUQUPNZN",
    #"ABRYCTUGVZXUPB",
    #"MVERZRLQDBHQ",
    #"GKJFHYXODIE",
    #"UGMNCBXCRLDEY",
    #"UGMNCBXCFLDFY",
    "HFXPCQYZVATXAWIZPVE",#upside down-----
    #"JKGFIJPMCWSAEK",#top down---
    #"JKGFIJPMCWSAFK",
    #"SKCDKJCDJCYQSZKTZJPXPWIRN",
    #"MQOLCSJTLGAJOKBSSBOMUPCE",
    #"RHZVIYQIYSXVNQXQWIOVWPJO",#top down---
    #"YQHUDTABGALLOWLS",
    #"VIOHIKNNGUAB",
    #"KOWVRSRWTMLDH",
]
keywords = [
    #"KEY",
    #"BANK",
    #"GOV",
    #"OUSTGOV",
    #"QUERY",
    #"USA",
    #"TXNAME",
    #"QUARZ",
    #"THIEF",
    #"AMEND",
    #"BYPAY",
    #"IFUSED",
    "USBERGE",
]
alphabets = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
alpha1 = alphabets
alpha2 = alphabets
alpha3 = alphabets
keys2 = []
for x in alpha2:
    for y in alpha3:
        keys2.append(x + y)

#plug = "YQ HU DT AB GA LL OW LS"
plug = ""
ringset = "SRH" #"DIE" #"XZR"

for k in range(len(alpha1)):
    key1 = alpha1[k]
    print("KEY 1: " + key1)
    for i in range(len(cipher_shorts)):
        for j in range(len(keys2)):
            keyset = key1 + keys2[j]
            engine = Enigma(ROTOR_UKW_K, ROTOR_I_K, ROTOR_II_K, ROTOR_III_K, key=keyset, plugs=plug, ring=ringset, debug=False)
            decoded = engine.encipher(cipher_shorts[i]).upper()
            for kk in range(len(keywords)):
                if isMatchFound(decoded, keywords, andAll=False):
                    t1 = cipher_shorts[i] + ": " + decoded + " keyword: " + keywords[kk] + ' -key- ' + keyset + ' -ring- ' + ringset
                    print(t1, sep="")
# Out:
# KEY 1: A
# KEY 1: B
# KEY 1: C
# KEY 1: D
# KEY 1: E
# KEY 1: F
# KEY 1: G
# KEY 1: H
# HFXPCQYZVATXAWIZPVE: USBERGEUIFEKSFGVWTZ keyword: USBERGE -key- HEV -ring- SRH
# KEY 1: I
# KEY 1: J
# KEY 1: K
# KEY 1: L
# KEY 1: M
# KEY 1: N
# KEY 1: O
# KEY 1: P
# KEY 1: Q
# KEY 1: R
# KEY 1: S
# KEY 1: T
# KEY 1: U
# KEY 1: V
# KEY 1: W
# KEY 1: X
# KEY 1: Y
# KEY 1: Z

# %%
# 8/29/2024 - fix keyset and ringset, change notches
cipher_shorts = [
    "FEWGDRHDDEEUMFFTEEMJXZR",#JQE
    #"UGMNCBXCFLDEY", #SQE
    #"HLMTAHGBGFNIV",#upside down-----
    #"MLMTAHGBGFNIV",
    #"ZUQUPNZN",
    #"ABRYCTUGVZXUPB",
    #"MVERZRLQDBHQ",
    #"GKJFHYXODIE",
    #"UGMNCBXCRLDEY",
    #"UGMNCBXCFLDFY",
    #"HFXPCQYZVATXAWIZPVE",#upside down-----
    #"JKGFIJPMCWSAEK",#top down---
    #"JKGFIJPMCWSAFK",
    #"SKCDKJCDJCYQSZKTZJPXPWIRN",
    #"MQOLCSJTLGAJOKBSSBOMUPCE",
    #"RHZVIYQIYSXVNQXQWIOVWPJO",#top down---
    #"YQHUDTABGALLOWLS",
    #"VIOHIKNNGUAB",
    #"KOWVRSRWTMLDH",
]
keywords = [
    #"KEY",
    #"BANK",
    #"GOV",
    #"OUSTGOV"
    "OUSTGOVPBANKIZMUBMHUVOG"
    #"QUERY"
    #"USA"
    #"TXNAME"
    #"QUARZ"
    #"THIEF"
]
alphabets = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
alpha1 = alphabets
alpha2 = alphabets
alpha3 = alphabets
keys2 = []
for x in alpha2:
    for y in alpha3:
        keys2.append(x + y)

#plug = "YQ HU DT AB GA LL OW LS"
plug = ""
ringset = "XZR"
zerokey = "GPV"

for k in range(len(alpha1)):
    key1 = alpha1[k]
    print("KEY 1: " + key1)
    for i in range(len(cipher_shorts)):
        for j in range(len(keys2)):
            keyset = key1 + keys2[j]
            engine = Enigma(ROTOR_UKW_K, ROTOR_I_K, ROTOR_II_K, ROTOR_III_K, key=zerokey, plugs=plug, ring=ringset, notchs=keyset, debug=False)
            decoded = engine.encipher(cipher_shorts[i]).upper()
            for kk in range(len(keywords)):
                if isMatchFound(decoded, keywords, andAll=False):
                    t1 = cipher_shorts[i] + ": " + decoded + " keyword: " + keywords[kk] + ' -notch- ' + keyset + ' -zerokey- ' + zerokey + ' -ring- ' + ringset
                    print(t1, sep="")
# Out:
# KEY 1: A
# KEY 1: B
# KEY 1: C
# KEY 1: D
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAA -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAB -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAC -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAD -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAE -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAF -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAG -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAH -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAI -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAJ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAK -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAL -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAM -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAN -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAO -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAP -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAQ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAR -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAS -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAT -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DAZ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBA -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBB -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBC -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBD -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBE -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBF -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBG -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBH -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBI -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBJ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBK -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBL -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBM -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBN -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBO -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBP -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBQ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBR -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBS -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBT -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DBZ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCA -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCB -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCC -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCD -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCE -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCF -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCG -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCH -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCI -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCJ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCK -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCL -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCM -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCN -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCO -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCP -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCQ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCR -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCS -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCT -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DCZ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDA -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDB -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDC -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDD -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDE -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDF -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDG -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDH -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDI -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDJ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDK -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDL -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDM -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDN -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDO -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDP -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDQ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDR -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDS -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDT -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DDZ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEA -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEB -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEC -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DED -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEE -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEF -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEG -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEH -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEI -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEJ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEK -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEL -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEM -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEN -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEO -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEP -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEQ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DER -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DES -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DET -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DEZ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFA -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFB -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFC -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFD -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFE -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFF -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFG -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFH -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFI -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFJ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFK -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFL -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFM -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFN -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFO -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFP -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFQ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFR -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFS -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFT -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DFZ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGA -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGB -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGC -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGD -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGE -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGF -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGG -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGH -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGI -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGJ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGK -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGL -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGM -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGN -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGO -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGP -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGQ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGR -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGS -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGT -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DGZ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHA -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHB -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHC -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHD -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHE -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHF -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHG -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHH -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHI -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHJ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHK -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHL -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHM -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHN -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHO -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHP -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHQ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHR -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHS -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHT -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DHZ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIA -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIB -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIC -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DID -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIE -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIF -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIG -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIH -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DII -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIJ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIK -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIL -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIM -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIN -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIO -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIP -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIQ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIR -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIS -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIT -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DIZ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJA -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJB -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJC -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJD -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJE -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJF -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJG -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJH -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJI -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJJ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJK -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJL -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJM -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJN -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJO -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJP -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJQ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJR -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJS -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJT -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DJZ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKA -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKB -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKC -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKD -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKE -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKF -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKG -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKH -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKI -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKJ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKK -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKL -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKM -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKN -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKO -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKP -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKQ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKR -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKS -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKT -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DKZ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLA -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLB -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLC -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLD -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLE -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLF -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLG -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLH -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLI -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLJ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLK -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLL -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLM -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLN -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLO -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLP -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLQ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLR -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLS -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLT -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DLZ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMA -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMB -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMC -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMD -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DME -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMF -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMG -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMH -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMI -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMJ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMK -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DML -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMM -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMN -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMO -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMP -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMQ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMR -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMS -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMT -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DMZ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNA -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNB -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNC -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DND -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNE -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNF -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNG -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNH -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNI -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNJ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNK -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNL -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNM -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNN -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNO -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNP -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNQ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNR -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNS -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNT -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DNZ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOA -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOB -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOC -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOD -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOE -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOF -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOG -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOH -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOI -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOJ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOK -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOL -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOM -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DON -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOO -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOP -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOQ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOR -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOS -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOT -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DOZ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPA -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPB -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPC -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPD -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPE -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPF -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPG -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPH -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPI -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPJ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPK -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPL -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPM -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPN -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPO -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPP -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPQ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPR -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPS -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPT -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DPZ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- DQA -key- GPV -ring- XZR
# ...
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GUT -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GUU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GUV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GUW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GUX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GUY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GUZ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVA -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVB -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVC -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVD -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVE -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVF -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVG -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVH -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVI -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVJ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVK -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVL -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVM -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVN -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVO -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVP -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVQ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVR -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVS -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVT -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GVZ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWA -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWB -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWC -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWD -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWE -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWF -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWG -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWH -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWI -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWJ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWK -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWL -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWM -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWN -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWO -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWP -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWQ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWR -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWS -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWT -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GWZ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXA -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXB -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXC -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXD -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXE -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXF -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXG -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXH -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXI -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXJ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXK -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXL -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXM -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXN -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXO -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXP -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXQ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXR -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXS -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXT -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GXZ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYA -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYB -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYC -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYD -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYE -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYF -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYG -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYH -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYI -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYJ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYK -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYL -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYM -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYN -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYO -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYP -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYQ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYR -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYS -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYT -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GYZ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZA -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZB -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZC -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZD -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZE -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZF -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZG -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZH -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZI -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZJ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZK -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZL -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZM -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZN -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZO -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZP -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZQ -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZR -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZS -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZT -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZU -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZV -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZW -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZX -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZY -key- GPV -ring- XZR
# FEWGDRHDDEEUMFFTEEMJXZR: OUSTGOVPBANKIZMUBMHUVOG keyword: OUSTGOVPBANKIZMUBMHUVOG -notch- GZZ -key- GPV -ring- XZR
# KEY 1: H
# KEY 1: I
# KEY 1: J
# KEY 1: K
# KEY 1: L
# KEY 1: M
# KEY 1: N
# KEY 1: O
# KEY 1: P
# KEY 1: Q
# KEY 1: R
# KEY 1: S
# KEY 1: T
# KEY 1: U
# KEY 1: V
# KEY 1: W
# KEY 1: X
# KEY 1: Y
# KEY 1: Z

# %%
# 8/29/2024 - fix keyset and ringset, change notches
cipher_shorts = [
    #"FEWGDRHDDEEUMFFTEEMJXZR",#JQE
    #"UGMNCBXCFLDEY", #SQE
    #"HLMTAHGBGFNIV",#upside down-----
    #"MLMTAHGBGFNIV",
    #"ZUQUPNZN",
    #"ABRYCTUGVZXUPB",
    #"MVERZRLQDBHQ",
    #"GKJFHYXODIE",
    #"UGMNCBXCRLDEY",
    #"UGMNCBXCFLDFY",
    #"HFXPCQYZVATXAWIZPVE",#upside down-----
    #"JKGFIJPMCWSAEK",#top down---
    #"JKGFIJPMCWSAFK",
    #"SKCDKJCDJCYQSZKTZJPXPWIRN",
    "MQOLCSJTLGAJOKBSSBOMUPCE",
    #"RHZVIYQIYSXVNQXQWIOVWPJO",#top down---
    #"YQHUDTABGALLOWLS",
    #"VIOHIKNNGUAB",
    #"KOWVRSRWTMLDH",
]
keywords = [
    #"KEY",
    #"BANK",
    #"GOV",
    #"OUSTGOV",
    #"OUSTGOVPBANKIZMUBMHUVOG",
    #"QUERY",
    #"USA",
    #"TXNAME",
    #"QUARZ",
    #"THIEF",
    "AMEND",
]
alphabets = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
alpha1 = alphabets
alpha2 = alphabets
alpha3 = alphabets
keys2 = []
for x in alpha2:
    for y in alpha3:
        keys2.append(x + y)

#plug = "YQ HU DT AB GA LL OW LS"
plug = ""
ringset = "AAA"

for k in range(len(alpha1)):
    key1 = alpha1[k]
    print("KEY 1: " + key1)
    for i in range(len(cipher_shorts)):
        for j in range(len(keys2)):
            keyset = key1 + keys2[j]
            engine = Enigma(ROTOR_UKW_K, ROTOR_I_K, ROTOR_II_K, ROTOR_III_K, key=keyset, plugs=plug, ring=ringset, debug=False)
            decoded = engine.encipher(cipher_shorts[i]).upper()
            for kk in range(len(keywords)):
                if isMatchFound(decoded, keywords, andAll=False):
                    t1 = cipher_shorts[i] + ": " + decoded + " keyword: " + keywords[kk] + ' -key- ' + keyset + ' -ring- ' + ringset
                    print(t1, sep="")
# Out:
# KEY 1: A
# KEY 1: B
# KEY 1: C
# KEY 1: D
# KEY 1: E
# KEY 1: F
# KEY 1: G
# KEY 1: H
# KEY 1: I
# KEY 1: J
# KEY 1: K
# KEY 1: L
# KEY 1: M
# KEY 1: N
# KEY 1: O
# KEY 1: P
# KEY 1: Q
# KEY 1: R
# KEY 1: S
# KEY 1: T
# KEY 1: U
# KEY 1: V
# KEY 1: W
# KEY 1: X
# KEY 1: Y
# MQOLCSJTLGAJOKBSSBOMUPCE: AMENDJDSIIEZKIUTARFHIQUL keyword: AMEND -key- YXT -ring- AAA
# KEY 1: Z

# %%
# notice that the maximum length of short ciphers is 25, less than 1 compared to the alphabets A to Z
cipher_shorts = [
    #"FEWGDRHDDEEUMFFTEEMJXZR",
    #"UGMNCBXCFLDBEY",
    #"GKJFHYXODIE",
    
    #"ABRYCTUGVZXUPB",
    #"HFXPCQYZVATXAWIZPVE",
    #"HLMTAHGBGFNIV",
    #"JKGFIJPMCWSAEK",
    #"KOWVRSRKWTMLDH",
    #"MQOLCSJTLGAJOKBSSBOMUPCE",
    "MVERZRLQDBHQ",
    #"RHZVIYQIYSXVNQXQWIOVWPJO",
    #"SKCDKJCDJCYQSZKTZJPXPWIRN",
    #"VIOHIKNNGUAB",
    #"YQHUDTABGALLOWLS",
    #"ZUQUPNZN"
]

# start with 'H', do 'G' at the end since it rotates the second rotor
alphabets = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
alpha1 = alphabets
alpha2 = alphabets
alpha3 = alphabets
keys2 = []
for x in alpha2:
    for y in alpha3:
        keys2.append(x + y)

for k in range(len(alpha1)):
    key1 = alpha1[k]
    print("KEY 1: " + key1)
    for i in range(len(cipher_shorts)):
        parsedWords = []
        decList1 = []
        decList2 = []
        for j in range(len(keys2)):
            keyset = key1 + keys2[j]
            #
            engine = Enigma(ROTOR_UKW_K, ROTOR_I_K, ROTOR_III_K, ROTOR_II_K, key=keyset, ring='AAA', debug=False)
            decoded = engine.encipher(cipher_shorts[i]).upper()
            parsed = ' '.join(wordninja.split(decoded))
            parsedWords.append(parsed + " : " + decoded + ": " + keyset)
        #
        if len(parsedWords):
            parsedWords.sort(reverse=False)
            saveSortedListAsTextFile(parsedWords, cipher_shorts[i] + "_132_ninja", key1)
# Out:
# KEY 1: A
# KEY 1: B
# KEY 1: C
# KEY 1: D
# KEY 1: E
# KEY 1: F
# KEY 1: G
# KEY 1: H
# KEY 1: I
# KEY 1: J
# KEY 1: K
# KEY 1: L
# KEY 1: M
# KEY 1: N
# KEY 1: O
# KEY 1: P
# KEY 1: Q
# KEY 1: R
# KEY 1: S
# KEY 1: T
# KEY 1: U
# KEY 1: V
# KEY 1: W
# KEY 1: X
# KEY 1: Y
# KEY 1: Z

# %%
# notice that the maximum length of short ciphers is 25, less than 1 compared to the alphabets A to Z
cipher_shorts = [
    #"FEWGDRHDDEEUMFFTEEMJXZR",
    #"UGMNCBXCFLDBEY",
    #"GKJFHYXODIE",
    
    #"ABRYCTUGVZXUPB",
    #"HFXPCQYZVATXAWIZPVE",
    #"HLMTAHGBGFNIV",
    #"JKGFIJPMCWSAEK",
    #"KOWVRSRKWTMLDH",
    #"MQOLCSJTLGAJOKBSSBOMUPCE",
    "MVERZRLQDBHQ",
    #"RHZVIYQIYSXVNQXQWIOVWPJO",
    #"SKCDKJCDJCYQSZKTZJPXPWIRN",
    #"VIOHIKNNGUAB",
    #"YQHUDTABGALLOWLS",
    #"ZUQUPNZN"
]

cipher_shorts_rev = []
for i in range(len(cipher_shorts)):
    cipher_shorts_rev.append(cipher_shorts[i][::-1])
#print(cipher_shorts_rev)

# start with 'H', do 'G' at the end since it rotates the second rotor
alphabets = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
alpha1 = alphabets
alpha2 = alphabets
alpha3 = alphabets
keys2 = []
for x in alpha2:
    for y in alpha3:
        keys2.append(x + y)

for k in range(len(alpha1)):
    key1 = alpha1[k]
    print("KEY 1: " + key1)
    for i in range(len(cipher_shorts)):
        parsedWords = []
        decList1 = []
        decList2 = []
        for j in range(len(keys2)):
            keyset = key1 + keys2[j]
            #
            engine = Enigma(ROTOR_UKW_K, ROTOR_I_K, ROTOR_II_K, ROTOR_III_K, key=keyset, ring='AAA', debug=False)
            decoded = engine.encipher(cipher_shorts_rev[i]).upper()
            parsed = ' '.join(wordninja.split(decoded))
            parsedWords.append(parsed + " : " + decoded + ": " + keyset)
        #
        if len(parsedWords):
            parsedWords.sort(reverse=False)
            saveSortedListAsTextFile(parsedWords, cipher_shorts[i] + "_123_ninja_rev", key1)
# Out:
# KEY 1: A
# KEY 1: B
# KEY 1: C
# KEY 1: D
# KEY 1: E
# KEY 1: F
# KEY 1: G
# KEY 1: H
# KEY 1: I
# KEY 1: J
# KEY 1: K
# KEY 1: L
# KEY 1: M
# KEY 1: N
# KEY 1: O
# KEY 1: P
# KEY 1: Q
# KEY 1: R
# KEY 1: S
# KEY 1: T
# KEY 1: U
# KEY 1: V
# KEY 1: W
# KEY 1: X
# KEY 1: Y
# KEY 1: Z

# %%
# notice that the maximum length of short ciphers is 25, less than 1 compared to the alphabets A to Z
cipher_shorts = [
    #"FEWGDRHDDEEUMFFTEEMJXZR",
    #"UGMNCBXCFLDBEY",
    #"GKJFHYXODIE",
    
    #"ABRYCTUGVZXUPB",
    #"HFXPCQYZVATXAWIZPVE",
    #"HLMTAHGBGFNIV",
    #"JKGFIJPMCWSAEK",
    #"KOWVRSRKWTMLDH",
    #"MQOLCSJTLGAJOKBSSBOMUPCE",
    "MVERZRLQDBHQ",
    #"RHZVIYQIYSXVNQXQWIOVWPJO",
    #"SKCDKJCDJCYQSZKTZJPXPWIRN",
    #"VIOHIKNNGUAB",
    #"YQHUDTABGALLOWLS",
    #"ZUQUPNZN"
]

# start with 'H', do 'G' at the end since it rotates the second rotor
alphabets = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
alpha1 = alphabets
alpha2 = alphabets
alpha3 = alphabets
keys2 = []
for x in alpha2:
    for y in alpha3:
        keys2.append(x + y)

for k in range(len(alpha1)):
    key1 = alpha1[k]
    print("KEY 1: " + key1)
    for i in range(len(cipher_shorts)):
        decList1 = []
        decList2 = []
        for j in range(len(keys2)):
            keyset = key1 + keys2[j]
            engine = Enigma(ROTOR_UKW_K, ROTOR_I_K, ROTOR_II_K, ROTOR_III_K, key=keyset, ring='AAA', debug=False)
            decoded = engine.encipher(cipher_shorts[i]).upper()
            if isFreeConsonantMoreThan(decoded, 3):
                decList2.append(decoded + ", keys: " + keyset + " : " + cipher_shorts[i])
            else:
                decList1.append(decoded + ", keys: " + keyset + " : " + cipher_shorts[i])
        if len(decList1) > 0:
            decList1.sort()
            saveSortedListAsTextFile(decList1, cipher_shorts[i] + "_123", key1)
        if len(decList2) > 0:
            decList2.sort()
            saveSortedListAsTextFile(decList2, cipher_shorts[i] + "_123", key1 + "_X")
# Out:
# ['QHBDQLRZREVM']
# KEY 1: A
# KEY 1: B
# KEY 1: C
# KEY 1: D
# KEY 1: E
# KEY 1: F
# KEY 1: G
# KEY 1: H
# KEY 1: I
# KEY 1: J
# KEY 1: K
# KEY 1: L
# KEY 1: M
# KEY 1: N
# KEY 1: O
# KEY 1: P
# KEY 1: Q
# KEY 1: R
# KEY 1: S
# KEY 1: T
# KEY 1: U
# KEY 1: V
# KEY 1: W
# KEY 1: X
# KEY 1: Y
# KEY 1: Z

# %%
k = "JQE"
r = "AAA"
secret = "FEWGDRHDDEEUMFFTEEMJXZR"
print('key = ', k, ', ring: ', r, '\n', 'secret: ', secret)

engine = Enigma(ROTOR_UKW_K, ROTOR_I_K, ROTOR_II_K, ROTOR_III_K, key=k, ring=r, debug=True)
text = engine.encipher(secret[0:23:1]).upper()

print(text)
# Out:
# key =  JQE , ring:  AAA
#  secret:  FEWGDRHDDEEUMFFTEEMJXZR
# I-K [>>>] J: F I
# II-K [>>>] Q: I N
# III-K [>>>] E: N U
# UKW-K [---] A: U V
# III-K [<<<] E: V J
# II-K [<<<] Q: J A
# I-K [<<<] J: A O
# I-K [turnover] ? = False, state = K, notchs = G
# I-K [notch] J --> K
# [states] : KQE
# I-K [>>>] K: E H
# II-K [>>>] Q: H X
# III-K [>>>] E: X F
# UKW-K [---] A: F G
# III-K [<<<] E: G D
# II-K [<<<] Q: D P
# I-K [<<<] K: P U
# I-K [turnover] ? = False, state = L, notchs = G
# I-K [notch] K --> L
# [states] : LQE
# I-K [>>>] L: W P
# II-K [>>>] Q: P D
# III-K [>>>] E: D G
# UKW-K [---] A: G F
# III-K [<<<] E: F X
# II-K [<<<] Q: X H
# I-K [<<<] L: H S
# I-K [turnover] ? = False, state = M, notchs = G
# I-K [notch] L --> M
# [states] : MQE
# I-K [>>>] M: G I
# II-K [>>>] Q: I N
# III-K [>>>] E: N U
# UKW-K [---] A: U V
# III-K [<<<] E: V J
# II-K [<<<] Q: J A
# I-K [<<<] M: A T
# I-K [turnover] ? = False, state = N, notchs = G
# I-K [notch] M --> N
# [states] : NQE
# I-K [>>>] N: D L
# II-K [>>>] Q: L V
# III-K [>>>] E: V A
# UKW-K [---] A: A I
# III-K [<<<] E: I M
# II-K [<<<] Q: M G
# I-K [<<<] N: G G
# I-K [turnover] ? = False, state = O, notchs = G
# I-K [notch] N --> O
# [states] : OQE
# I-K [>>>] O: R Y
# II-K [>>>] Q: Y S
# III-K [>>>] E: S R
# UKW-K [---] A: R H
# III-K [<<<] E: H T
# II-K [<<<] Q: T S
# I-K [<<<] O: S O
# I-K [turnover] ? = False, state = P, notchs = G
# I-K [notch] O --> P
# [states] : PQE
# I-K [>>>] P: H N
# II-K [>>>] Q: N Q
# III-K [>>>] E: Q K
# UKW-K [---] A: K S
# III-K [<<<] E: S I
# II-K [<<<] Q: I B
# I-K [<<<] P: B V
# I-K [turnover] ? = False, state = Q, notchs = G
# I-K [notch] P --> Q
# [states] : QQE
# I-K [>>>] Q: D D
# II-K [>>>] Q: D W
# III-K [>>>] E: W Y
# UKW-K [---] A: Y J
# III-K [<<<] E: J O
# II-K [<<<] Q: O W
# I-K [<<<] Q: W P
# I-K [turnover] ? = False, state = R, notchs = G
# I-K [notch] Q --> R
# [states] : RQE
# I-K [>>>] R: D W
# II-K [>>>] Q: W O
# III-K [>>>] E: O J
# UKW-K [---] A: J Y
# III-K [<<<] E: Y W
# II-K [<<<] Q: W D
# I-K [<<<] R: D B
# I-K [turnover] ? = False, state = S, notchs = G
# I-K [notch] R --> S
# [states] : SQE
# I-K [>>>] S: E K
# II-K [>>>] Q: K C
# III-K [>>>] E: C D
# UKW-K [---] A: D T
# III-K [<<<] E: T K
# II-K [<<<] Q: K C
# I-K [<<<] S: C A
# I-K [turnover] ? = False, state = T, notchs = G
# I-K [notch] S --> T
# [states] : TQE
# I-K [>>>] T: E Q
# II-K [>>>] Q: Q P
# III-K [>>>] E: P M
# UKW-K [---] A: M B
# III-K [<<<] E: B L
# II-K [<<<] Q: L O
# I-K [<<<] T: O N
# I-K [turnover] ? = False, state = U, notchs = G
# I-K [notch] T --> U
# [states] : UQE
# I-K [>>>] U: U X
# II-K [>>>] Q: X G
# III-K [>>>] E: G N
# UKW-K [---] A: N Z
# III-K [<<<] E: Z Z
# II-K [<<<] Q: Z F
# I-K [<<<] U: F K
# I-K [turnover] ? = False, state = V, notchs = G
# I-K [notch] U --> V
# [states] : VQE
# I-K [>>>] V: M F
# II-K [>>>] Q: F Z
# III-K [>>>] E: Z Z
# UKW-K [---] A: Z N
# III-K [<<<] E: N G
# II-K [<<<] Q: G X
# I-K [<<<] V: X I
# I-K [turnover] ? = False, state = W, notchs = G
# I-K [notch] V --> W
# [states] : WQE
# I-K [>>>] W: F T
# II-K [>>>] Q: T A
# III-K [>>>] E: A L
# UKW-K [---] A: L Q
# III-K [<<<] E: Q F
# II-K [<<<] Q: F M
# I-K [<<<] W: M Z
# I-K [turnover] ? = False, state = X, notchs = G
# I-K [notch] W --> X
# [states] : XQE
# I-K [>>>] X: F J
# II-K [>>>] Q: J E
# III-K [>>>] E: E P
# UKW-K [---] A: P W
# III-K [<<<] E: W H
# II-K [<<<] Q: H R
# I-K [<<<] X: R M
# I-K [turnover] ? = False, state = Y, notchs = G
# I-K [notch] X --> Y
# [states] : YQE
# I-K [>>>] Y: T D
# II-K [>>>] Q: D W
# III-K [>>>] E: W Y
# UKW-K [---] A: Y J
# III-K [<<<] E: J O
# II-K [<<<] Q: O W
# I-K [<<<] Y: W U
# I-K [turnover] ? = False, state = Z, notchs = G
# I-K [notch] Y --> Z
# [states] : ZQE
# I-K [>>>] Z: E T
# II-K [>>>] Q: T A
# III-K [>>>] E: A L
# UKW-K [---] A: L Q
# III-K [<<<] E: Q F
# II-K [<<<] Q: F M
# I-K [<<<] Z: M B
# I-K [turnover] ? = False, state = A, notchs = G
# I-K [notch] Z --> A
# [states] : AQE
# I-K [>>>] A: E Z
# II-K [>>>] Q: Z B
# III-K [>>>] E: B O
# UKW-K [---] A: O X
# III-K [<<<] E: X R
# II-K [<<<] Q: R V
# I-K [<<<] A: V M
# I-K [turnover] ? = False, state = B, notchs = G
# I-K [notch] A --> B
# [states] : BQE
# I-K [>>>] B: M W
# II-K [>>>] Q: W O
# III-K [>>>] E: O J
# UKW-K [---] A: J Y
# III-K [<<<] E: Y W
# II-K [<<<] Q: W D
# I-K [<<<] B: D H
# I-K [turnover] ? = False, state = C, notchs = G
# I-K [notch] B --> C
# [states] : CQE
# I-K [>>>] C: J I
# II-K [>>>] Q: I N
# III-K [>>>] E: N U
# UKW-K [---] A: U V
# III-K [<<<] E: V J
# II-K [<<<] Q: J A
# I-K [<<<] C: A U
# I-K [turnover] ? = False, state = D, notchs = G
# I-K [notch] C --> D
# [states] : DQE
# I-K [>>>] D: X I
# II-K [>>>] Q: I N
# III-K [>>>] E: N U
# UKW-K [---] A: U V
# III-K [<<<] E: V J
# II-K [<<<] Q: J A
# I-K [<<<] D: A V
# I-K [turnover] ? = False, state = E, notchs = G
# I-K [notch] D --> E
# [states] : EQE
# I-K [>>>] E: Z O
# II-K [>>>] Q: O L
# III-K [>>>] E: L B
# UKW-K [---] A: B M
# III-K [<<<] E: M P
# II-K [<<<] Q: P Q
# I-K [<<<] E: Q O
# I-K [turnover] ? = False, state = F, notchs = G
# I-K [notch] E --> F
# [states] : FQE
# I-K [>>>] F: R X
# II-K [>>>] Q: X G
# III-K [>>>] E: G N
# UKW-K [---] A: N Z
# III-K [<<<] E: Z Z
# II-K [<<<] Q: Z F
# I-K [<<<] F: F G
# I-K [turnover] ? = True, state = G, notchs = G
# II-K [turnover] ? = False, state = R, notchs = M
# II-K [notch] Q --> R
# I-K [notch] F --> G
# [states] : GRE
# OUSTGOVPBANKIZMUBMHUVOG

# %%
plugs = "YQ HU DT AB GA LL OW LS"
print(plugs.split())

p = [(elem[0], elem[1]) for elem in plugs.split()]
print(p)
# Out:
# ['YQ', 'HU', 'DT', 'AB', 'GA', 'LL', 'OW', 'LS']
# [('Y', 'Q'), ('H', 'U'), ('D', 'T'), ('A', 'B'), ('G', 'A'), ('L', 'L'), ('O', 'W'), ('L', 'S')]
